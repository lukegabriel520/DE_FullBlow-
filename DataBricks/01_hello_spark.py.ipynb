# %%
data = [
    (101, "Ana", "PH"),
    (102, "Ben", "PH"),
    (103, "Cara", "AE"),
]
df = spark.createDataFrame(data, ["customer_id", "first_name", "country"])

df.printSchema()
df.show()
print("row_count:", df.count())
